# %% [markdown]
# # NEWRVC: High-Performance Engine + Ultimate Workflows 🚀
# Welcome to the NewRVC Google Colab!
#
# It merges the core engine of `codename-rvc-fork-4` (RingFormer, PCPH-GAN, Spin) with the intuitive workflows of `Ultimate RVC` (Auto YouTube Download, Audio-Separator for MDX Kim Vocals 2 / Demucs).
#
# ## 1. Install Dependencies

# %%
# Clone the repository from GitHub
# !git clone https://github.com/DDME36/NEWRVC.git

import os
os.chdir('/content/NEWRVC')

# Install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Start the Gradio UI
# This will automatically download any missing core models on first run and expose a public Gradio link.

# %%
# !python app.py --share
