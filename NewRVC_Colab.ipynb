# %% [markdown]
# ## 🚀 NEWRVC (Colab Edition)
# **Welcome to NEWRVC!** A fully redesigned, high-performance RVC setup that combines the robust **codename-rvc-fork-4** core engine with a **clean, modern White/Red UI** inspired by Ultimate RVC.
#
# —
# #### 🔥 What's New:
# - **1-Click AI Song Cover**: Download YouTube → Separate Audio → Convert Vocals → Auto-Mix all in one page.
# - **Smart Model Downloader**: Enter a URL and a custom model name, and it automatically extracts and organizes your `.pth` and `.index` files perfectly.
# - **Ringformer & PCPH-GAN**: Full support for cutting-edge models in the Train tab.

# %%
# @title 1. Install Dependencies & Setup Environment
# @markdown This usually takes 1-2 minutes to pull the codebase and setup Python.
import os

# !git clone https://github.com/DDME36/NEWRVC.git
# %cd NEWRVC

# We use `uv` for lightning-fast and isolated installation.
# !curl -LsSf https://astral.sh/uv/install.sh | sh
os.environ["PATH"] += ":/root/.local/bin"

# !uv venv .venv --python 3.11
# !uv pip install -r requirements.txt

print("\n✅ Environment is fully prepared!")

# %%
# @title 2. Launch NEWRVC
# @markdown Click the `public URL` starting with `https://XXXX.gradio.live` to open the app!

# Force matplotlib to stay headless to prevent crashes when generating analyzer plots behind the scenes.
# !MPLBACKEND=agg .venv/bin/python app.py --share
