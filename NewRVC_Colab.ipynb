# %% [markdown]
# # NEWRVC: High-Performance Engine + Ultimate Workflows 🚀
#
# Merges the core engine of `codename-rvc-fork-4` (RingFormer, PCPH-GAN, Spin) with intuitive workflows (Auto YouTube Download, Audio-Separator).
#
# Simply click `Runtime` → `Run all`. Wait for the public Gradio URL to appear in the final cell and click on it.

# %%
# @title 0: Initialize notebook
import os
from IPython.display import clear_output

# %%
# @title 1: Clone repository
# !git clone https://github.com/DDME36/NEWRVC.git /content/NEWRVC
# %cd /content/NEWRVC

# %%
# @title 2: Install dependencies (using uv + Python 3.11 venv)
# !apt install -y python3-dev unzip
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ["PATH"] = os.path.expanduser("~/.local/bin:") + os.environ["PATH"]

# Create a virtual environment with Python 3.11 and install all dependencies
# !uv venv .venv --python 3.11
# !uv pip install -r requirements.txt --python .venv/bin/python

# %%
# @title 3: Run NEWRVC
# Override Colab's default matplotlib backend which causes errors in our venv
import os
os.environ["MPLBACKEND"] = "agg"

# !.venv/bin/python app.py --share
